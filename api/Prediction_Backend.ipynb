# %%
from flask import Flask, request, jsonify
import librosa
import numpy as np
from tensorflow.keras.models import load_model
from pyngrok import ngrok

model_path = "/content/drive/MyDrive/CNN-Mel-Spectrogram.h5"
model = load_model(model_path)

# Classes
classes = [
    "YAF_sad",
    "YAF_pleasant_surprised",
    "YAF_neutral",
    "YAF_angry",
    "YAF_fear",
    "OAF_Sad",
    "YAF_happy",
    "YAF_disgust",
    "OAF_Pleasant_surprise",
    "OAF_happy",
    "OAF_neutral",
    "OAF_Fear",
    "OAF_angry",
    "OAF_disgust"
]

app = Flask(__name__)

@app.route("/predict", methods=["POST"])
def predict():
    if "file" not in request.files:
        return jsonify({"error": "No file uploaded"})

    try:
        file = request.files["file"]

        y, sr = librosa.load(file, sr=22050)
        mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

        # Fix width
        max_len = 128
        if mel_spec_db.shape[1] < max_len:
            pad_width = max_len - mel_spec_db.shape[1]
            mel_spec_db = np.pad(mel_spec_db, pad_width=((0,0),(0,pad_width)), mode='constant')
        else:
            mel_spec_db = mel_spec_db[:, :max_len]

        # Reshape
        mel_spec_db = np.expand_dims(mel_spec_db, axis=-1)
        mel_spec_db = np.expand_dims(mel_spec_db, axis=0)

        # Predict
        pred = model.predict(mel_spec_db)
        pred_class = classes[np.argmax(pred)]
        confidence = float(np.max(pred))  # highest probability

        return jsonify({"predicted_class": pred_class, "confidence": confidence})

    except Exception as e:
        return jsonify({"error": str(e)})




public_url = ngrok.connect(5000)
print("Public URL:", public_url)

# Run Flask app
app.run(host="0.0.0.0", port=5000)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Public URL: NgrokTunnel: "https://ba47bd8d2de3.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# INFO:werkzeug:127.0.0.1 - - [14/Jan/2026 04:42:24] "POST /predict HTTP/1.1" 200 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# INFO:werkzeug:127.0.0.1 - - [14/Jan/2026 04:42:39] "POST /predict HTTP/1.1" 200 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# INFO:werkzeug:127.0.0.1 - - [14/Jan/2026 04:42:50] "POST /predict HTTP/1.1" 200 -
# ...
